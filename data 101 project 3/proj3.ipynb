# %%
# Initialize Otter
import otter
grader = otter.Notebook("proj3.ipynb")

# %% [markdown]
# # Project 3: Data Transformation
#
# ## Due Date: Friday 10/28, 11:59 PM
#
# ## Assignment Details
#
# In this project, we'll be working with one month of data from sensors in buildings at UC Berkeley. This is a very typical real-world dataset---i.e. it's kind of a mess. The full dataset contains a giant `data` table of sensor readings that is many billions of readings over the course of a decade; we will look at a single month of that data. It also contains a variety of other tables that contextualize the readings.
#
# The schema for the database is shown below. Sometimes people think that if the data is a nice schema, then it's ready to go! We'll see about that.
#
# **Note:** Each line represents a relationship between the two fields. The side of the line diverging to three lines / arrows suggests the "many" side of the relationship, while the side of the line converging to one arrow suggests the "one" side of the relationship.

# %% [markdown]
# <img src="data/schema.png">

# %% [markdown]
# ## Logistics & Scoring Breakdown
#
# For Data 101 students, this project is worth 15% of your grade. For Info 258 students, this project is worth 12% of your grade.
#
# Each coding question has **both public tests and hidden tests**. Roughly 50% of your coding grade will be made up of your score on the public tests released to you, while the remaining 50% will be made up of unreleased hidden tests. Free-response questions will be manually graded.
#
# This is an **individual project**. However, you’re welcome to collaborate with any other student in the class as long as it’s within the academic honesty guidelines.
#
# Question | Points
# --- | ---
# 1a	| 1
# 1b  | 1
# 1c	| 1
# 1d	| 2
# 2a	| 3
# 2b	| 1
# 3a	| 0
# 3b	| 1
# 3c	| 1
# 3d  | 0
# 3e  | 2
# 4a	| 2
# 4b	| 2
# 4c	| 3
# **Total** | 20

# %%
# Run this cell to set up imports
import numpy as np
import pandas as pd

# %%
# %reload_ext sql
# %sql postgresql://jovyan@127.0.0.1:5432/template1

# %% [markdown]
# ## Loading Up the Database
# To load the database, run the following cell.
#
# **IMPORTANT NOTE:** In contrary to previous projects, the database does not reload automatically upon running the following loading cell. If you would like to reload the database (e.g. if your database is modified in undesirable ways), **first restart the kernel**, and then run `!psql -h localhost -c 'DROP DATABASE IF EXISTS ucb_buildings'` in another cell **before** running the cell below.

# %%
import subprocess
import os
import warnings

call = subprocess.run(["psql", "-h", "localhost", \
                       "-tAc", "SELECT 1 FROM pg_database WHERE datname='ucb_buildings'", "template1"], \
                      stdout=subprocess.PIPE, text=True)

if call.stdout != "1\n":
    print("Loading database...")
    os.system("gunzip -c data/proj3.sql.gz | psql -h localhost -d template1 -f -")
else:
    print("Database was previously loaded.")
# Out:
# Database was previously loaded.

# %% [markdown]
# Now, run the following cell to connect to the `ucb_buildings` database. There should be no errors after running the following cell.

# %%
# %sql postgresql://jovyan@127.0.0.1:5432/ucb_buildings

# %% [markdown]
# Run the following cell for grading purposes.

# %%
# !mkdir -p results

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Question 1: Unboxing the Data
#
# ### Question 1a
#
# Note that the `data` table, in the full database, is billions of rows. What do you notice about the design of the database schema that helps support the large amount of data?
#
# **Hint:** There is no need to examine any data here. What is a technique learned in [lecture 15](https://docs.google.com/presentation/d/1GogwyAylHrJoxer_apIkgnWDqC9LxTQ8/edit)? Define that technique.
#
# <!--
# BEGIN QUESTION
# name: q1a
# manual: true
# points: 1
# -->

# %% [markdown]
# The data is taking normalization. Normalization is creating a table and establishing relationships between the small bits of data that are stored in smaller tables. Normalization gets r

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# ### Question 1b
#
# The diagram claims that `buildings_site_mapping` has a many-to-many relationship with `real_estate_metadata`. Let's validate that.
#
# Below is an example of `json_agg` being used with a table; you will need to do this in the next two parts.

# %%
# %%sql
# SELECT b.site, json_agg(b) from buildings_site_mapping b GROUP BY b.site LIMIT 5;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 5 rows affected.
# [('Sutardja Dai Hall', [{'site': 'Sutardja Dai Hall', 'building': 'SUTARDJA DAI'}]),
#  ('Le Conte Hall', [{'site': 'Le Conte Hall', 'building': 'LE CONTE'}]),
#  ('Hildebrand Hall', [{'site': 'Hildebrand Hall', 'building': 'HILDEBRA ND'}]),
#  ('Stephens Hall', [{'site': 'Stephens Hall', 'building': 'STEPHENS'}]),
#  ('2000 Carleton Street', [{'site': '2000 Carleton Street', 'building': 'CARLETO2 000'}])]

# %%
# %sql SELECT DISTINCT * FROM buildings_site_mapping LIMIT 5
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 5 rows affected.
# [('Soda Hall New (as of 1/12/12)', 'SODA'),
#  ('Stanley Hall', 'STANLEY'),
#  ('SRB1 and Oxford Tract', 'OXFORD INSCT'),
#  ('Chavez Center', 'CHAVEZ'),
#  ('Strawberry Canyon Center', 'STRAWBE RY RR')]

# %%
# %sql SELECT DISTINCT * FROM real_estate_metadata LIMIT 5
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 5 rows affected.
# [('RIVERSIDE', 'P5711', 'RUBIDOUX QUA', 'GLENWOO D45 D01R IVE', 'RIVERSIDE', 'RIVERSIDE', 'GENERAL', 2098, 2000, 1, '1962', 'UC', 'P', 118526.0),
#  ('SAN DIEGO', '7125', 'MATTHEW SHOP', 'CORE CAMPUS', 'LA JOLLA', 'SAN DIEGO', 'RESIDENTIAL', 1529, 1151, 1, '1981', 'UC', 'P', nan),
#  ('RIVERSIDE', 'P5422', 'GH5', 'CORE CAMPUS', 'RIVERSIDE', 'RIVERSIDE', 'GENERAL', 233, 208, 1, '1956', 'UC', 'P', 202318.0),
#  ('RIVERSIDE', 'P5131', 'CC UTAH 3354', 'CORE CAMPUS', 'RIVERSIDE', 'RIVERSIDE', 'RESIDENTIAL', 1340, 1250, 1, '1941', 'UF', 'P', 8275.0),
#  ('SANTA BARBARA', '8381', 'PARK SERV', 'CORE CAMPUS', 'SANTA BARBARA', 'SANTA BARBARA', 'GENERAL', 1617, 1386, 1, '1985', 'UP', 'R', 3753.0)]

# %% [markdown]
# Find the **distinct** values of `buildings_site_mapping.building` that match multiple tuples in `real_estate_metadata.building_name`, and for each such value of `buildings_site_mapping.building` return the matches as JSON via `json_agg(real_estate_metadata)`. Your output should contain the building and the `json_agg` in that order. Order your final result by building.
#
# **Hint:** You should use a CTE to find the distinct buildings of `buildings_site_mapping` before applying necessary table joins.

# %%
# %%sql result_1b <<
# WITH b AS
#     (SELECT DISTINCT buildings_site_mapping.building from buildings_site_mapping)
# SELECT b.building,json_agg(real_estate_metadata) from b
# JOIN real_estate_metadata ON b.building = real_estate_metadata.building_name
# GROUP BY b.building
# HAVING COUNT(b.building) > 1
# ORDER BY b.building
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 5 rows affected.
# Returning data to local variable result_1b

# %%
result_1b
# Out:
# [('ALUMNI HOUSE', [{'location': 'BERKELEY', 'building': '1215', 'building_name': 'ALUMNI HOUSE', 'address': 'CORE C22A2M0PUS', 'city_name': 'BERKELEY', 'county': 'ALAME ... (589 characters truncated) ... SAN', 'category': 'HEALTH SCIENCE', 'osfg': 7217, 'bldg_asf': 5079, 'levels': 3, 'year': '1915', 'owner': 'UP', 'mp_code': 'P', 'book_value': 135923}]),
#  ('CAMPBELL', [{'location': 'BERKELEY', 'building': '1027', 'building_name': 'CAMPBELL', 'address': 'CORE C28A5M0PUS', 'city_name': 'BERKELEY', 'county': 'ALAMEDA', ... (300 characters truncated) ... GELES', 'category': 'GENERAL', 'osfg': 55401, 'bldg_asf': 32619, 'levels': 5, 'year': '1954', 'owner': 'UC', 'mp_code': 'P', 'book_value': 6247192.0}]),
#  ('HERTZ', [{'location': 'BERKELEY', 'building': '1423', 'building_name': 'HERTZ', 'address': 'CORE CAMPUS', 'city_name': 'BERKELEY', 'county': 'ALAMEDA', 'categ ... (273 characters truncated) ... nty': 'ALAMEDA', 'category': 'GENERAL', 'osfg': 10904, 'bldg_asf': 8183, 'levels': 1, 'year': '1976', 'owner': 'UC', 'mp_code': 'P', 'book_value': 0}]),
#  ('SOUTH', [{'location': 'BERKELEY', 'building': '1484', 'building_name': 'SOUTH', 'address': 'CORE CAMPUS', 'city_name': 'BERKELEY', 'county': 'ALAMEDA', 'categ ... (270 characters truncated) ... 'YOLO', 'category': 'GENERAL', 'osfg': 26594, 'bldg_asf': 15323, 'levels': 4, 'year': '1912', 'owner': 'UC', 'mp_code': 'P', 'book_value': 3585399.0}]),
#  ('SPROUL', [{'location': 'BERKELEY', 'building': '1210', 'building_name': 'SPROUL', 'address': 'CORE 2C6A0M0PUS', 'city_name': 'BERKELEY', 'county': 'ALAMEDA', ' ... (570 characters truncated) ... RSIDE', 'category': 'GENERAL', 'osfg': 80988, 'bldg_asf': 45532, 'levels': 5, 'year': '1965', 'owner': 'UC', 'mp_code': 'P', 'book_value': 1296147.0}])]

# %%
# Do not delete/edit this cell
result_1b.DataFrame().to_csv('results/result_1b.csv', index=False)

# %%
grader.check("q1b")
# Out:
# q1b results: All test cases passed!

# %% [markdown]
# ### Question 1c
#
# Now find examples of many matches in the opposite direction. For each distinct `real_estate_metadata.building_name` value, find the ones that have multiple matches in `buildings_site_mapping.building`, and for each return a `json_agg` of the multiple values for `buildings_site_mapping`. Your output should contain the building name and the `json_agg` in that order. Order your final result by building name.
#
# **Hint:** You should use a CTE to find the distinct building names of `real_estate_metadata` before applying necessary table joins.

# %%
# %%sql result_1c <<
# WITH r AS
#     (SELECT DISTINCT real_estate_metadata.building_name from real_estate_metadata)
# SELECT r.building_name,json_agg(buildings_site_mapping) from r
# JOIN buildings_site_mapping ON buildings_site_mapping.building = r.building_name
# GROUP BY r.building_name
# HAVING COUNT(r.building_name) > 1
# ORDER BY r.building_name
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 4 rows affected.
# Returning data to local variable result_1c

# %%
# Do not delete/edit this cell
result_1c.DataFrame().to_csv('results/result_1c.csv', index=False)

# %%
result_1c
# Out:
# [('EDWARDS FLD', [{'site': 'Edwards Stadium West', 'building': 'EDWARDS FLD'}, {'site': 'Edwards Stadium East', 'building': 'EDWARDS FLD'}]),
#  ('FAC CLUB', [{'site': 'Womens Faculty Club', 'building': 'FAC CLUB'}, {'site': "Men's Faculty Club", 'building': 'FAC CLUB'}]),
#  ('HAAS STU BLD', [{'site': 'Haas School of Business', 'building': 'HAAS STU BLD'}, {'site': 'Haas School Student Services (Water)', 'building': 'HAAS STU BLD'}]),
#  ('SIMON', [{'site': 'Boalt and Simon Hall', 'building': 'SIMON'}, {'site': 'Simpson Center', 'building': 'SIMON'}])]

# %%
grader.check("q1c")
# Out:
# q1c results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 1d
#
# Do you see any issues with the schema given? In particular, please address the two questions below:
# - Can you uniquely determine the building given the sensor data? Why? (**Hint:** given a row in the `data` table, can you determine a **uniquely** associated row in `real_estate_metadata` table? Your answer should draw insights from 1b.)
# - Could `buildings_site_mapping.building` be a valid foreign key pointing to `real_estate_metadata.building_name`? (**Hint:** think about the definition / constraints of a foreign key.)
#
# <!--
# BEGIN QUESTION
# name: q1d
# manual: true
# points: 2
# -->

# %% [markdown]
# We can not uniquely determine the building given in the sensor data. There is a many to many relationship because there are duplicate keys pointing to the real_estate_metadata.building_name so there can not be a valid foreign key.

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# ## Question 2: Looking for Outliers in the Readings
# Physical sensors like the ones generating this data are notorious for producing crazy outliers on occasion. In this section we'll do a little data cleaning of the outliers.
#
# All the readings from all different kinds of sensors are mixed together in the `data` table. This hodgepodge of mixed readings is going to require us to do some extra work to look for outliers. Let's get started.
#
# ### Question 2a: Outlier Detection
#
# Let's find the outlying values *for each sensor id*. We'll call something an outlier if it is **3 Hampel X84 intervals** away from the median. If
#
# Specifically, create a view `labeled_data` that contains all of the columns in `data` and adds three additional columns at the far right:
#   - `median` containing the median using `percentile_disc`
#   - `mad` containing the Median Absolute Deviation (MAD),
#   - `outlier` that contains `true` for the outlier readings and `false` for the rest. **Also,** for data points where the mad is 0, set this to `false`.

# %%
# %sql SELECT * FROM data LIMIT 5
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 5 rows affected.
# [(datetime.datetime(2018, 6, 12, 23, 0, 9, tzinfo=datetime.timezone.utc), 'a3d3326f-20ab-5f1d-97c7-f3084df43f06', 65182.74),
#  (datetime.datetime(2018, 6, 12, 22, 45, 9, tzinfo=datetime.timezone.utc), 'a3d3326f-20ab-5f1d-97c7-f3084df43f06', 65182.51),
#  (datetime.datetime(2018, 6, 12, 22, 30, 9, tzinfo=datetime.timezone.utc), 'a3d3326f-20ab-5f1d-97c7-f3084df43f06', 65182.27),
#  (datetime.datetime(2018, 6, 12, 22, 15, 10, tzinfo=datetime.timezone.utc), 'a3d3326f-20ab-5f1d-97c7-f3084df43f06', 65182.02),
#  (datetime.datetime(2018, 6, 12, 22, 0, 9, tzinfo=datetime.timezone.utc), 'a3d3326f-20ab-5f1d-97c7-f3084df43f06', 65181.77)]

# %%
# %sql DROP VIEW labeled_data;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# DependentObjectsStillExist: cannot drop view labeled_data because other objects depend on it
# DETAIL:  view cleaned_data depends on view labeled_data
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 get_ipython().run_line_magic('sql', 'DROP VIEW labeled_data;')
#
# File /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2309, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2307     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2308 with self.builtin_trap:
# -> 2309     result = fn(*args, **kwargs)
#    2310 return result
#
# File /opt/conda/lib/python3.9/site-packages/sql/magic.py:217, in SqlMagic.execute(self, line, cell, local_ns)
#     214     return
#     216 try:
# --> 217     result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     219     if (
#     220         result is not None
#     221         and not isinstance(result, str)
#    (...)
#     224         # Instead of returning values, set variables directly in the
#     225         # users namespace. Variable names given by column names
#     227         if self.autopandas:
#
# File /opt/conda/lib/python3.9/site-packages/sql/run.py:367, in run(conn, sql, config, user_namespace)
#     365 else:
#     366     txt = sqlalchemy.sql.text(statement)
# --> 367     result = conn.session.execute(txt, user_namespace)
#     368 _commit(conn=conn, config=config)
#     369 if result and config.feedback:
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1380, in Connection.execute(self, statement, *multiparams, **params)
#    1376     util.raise_(
#    1377         exc.ObjectNotExecutableError(statement), replace_context=err
#    1378     )
#    1379 else:
# -> 1380     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:333, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     329 def _execute_on_connection(
#     330     self, connection, multiparams, params, execution_options, _force=False
#     331 ):
#     332     if _force or self.supports_execution:
# --> 333         return connection._execute_clauseelement(
#     334             self, multiparams, params, execution_options
#     335         )
#     336     else:
#     337         raise exc.ObjectNotExecutableError(self)
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1572, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1560 compiled_cache = execution_options.get(
#    1561     "compiled_cache", self.engine._compiled_cache
#    1562 )
#    1564 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1565     dialect=dialect,
#    1566     compiled_cache=compiled_cache,
#    (...)
#    1570     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1571 )
# -> 1572 ret = self._execute_context(
#    1573     dialect,
#    1574     dialect.execution_ctx_cls._init_compiled,
#    1575     compiled_sql,
#    1576     distilled_params,
#    1577     execution_options,
#    1578     compiled_sql,
#    1579     distilled_params,
#    1580     elem,
#    1581     extracted_params,
#    1582     cache_hit=cache_hit,
#    1583 )
#    1584 if has_events:
#    1585     self.dispatch.after_execute(
#    1586         self,
#    1587         elem,
#    (...)
#    1591         ret,
#    1592     )
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2124, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2122     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2123 elif should_wrap:
# -> 2124     util.raise_(
#    2125         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126     )
#    2127 else:
#    2128     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                 break
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#    1905     self.dispatch.after_cursor_execute(
#    1906         self,
#    1907         cursor,
#    (...)
#    1911         context.executemany,
#    1912     )
#
# File /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# InternalError: (psycopg2.errors.DependentObjectsStillExist) cannot drop view labeled_data because other objects depend on it
# DETAIL:  view cleaned_data depends on view labeled_data
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
# [SQL: DROP VIEW labeled_data;]
# (Background on this error at: https://sqlalche.me/e/14/2j85)

# %%
# %%sql result_2a <<
# CREATE OR REPLACE VIEW labeled_data AS
# WITH med AS(
#     SELECT data.id, percentile_disc(0.5) WITHIN GROUP (ORDER BY value) as median FROM data GROUP BY data.id),
#  mad AS(
#     SELECT data.id, data.value, med.median, ABS(data.value - med.median) as absmed FROM data JOIN med on med.id = data.id),
# med_mad AS(
#     SELECT mad.id, mad.median, percentile_disc(0.5) WITHIN GROUP (ORDER BY absmed) as MAD FROM mad GROUP BY mad.id,mad.median)
#
#
#
# SELECT data.*, med_mad.median as median, med_mad.mad as mad,
#     CASE WHEN med_mad.mad = 0 THEN false
#     WHEN abs(data.value - med_mad.median) >  3 * 1.4826* med_mad.mad  THEN true
#     END AS outlier
# FROM med_mad NATURAL JOIN data;
#
#
#
# SELECT * FROM labeled_data WHERE outlier ORDER BY id, time LIMIT 100;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# 100 rows affected.
# Returning data to local variable result_2a

# %%
# Do not delete/edit this cell
result_2a.DataFrame().to_csv('results/result_2a.csv', index=False)

# %%
grader.check("q2a")
# Out:
# q2a results: All test cases passed!

# %% [markdown]
# ### Question 2b: Outlier Handling (Winsorization)
#
# In this step we'll define a view `cleaned_data` over all the columns of `labeled_data` and one additional column on the far right called `clean_value`. This column will contain a copy of `data.value` if that value is not an outlier. For outliers, it should contain the value Winsorized to the nearest outlier boundary value (3 Hampel X84 intervals from the median). If the MAD is 0, then the cleaned value should be the same as the original value.

# %%
# %sql DROP VIEW cleaned_data
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# []

# %%
# %%sql result_2b <<
# CREATE OR REPLACE VIEW cleaned_data AS
#
#
# SELECT l.*,
#     CASE WHEN l.mad = 0 then l.value
#     WHEN l.value <  l.median then l.median -  3 * 1.4826* l.mad
#     WHEN l.value > l.median then l.median + 3 * 1.4826* l.mad
#     END AS clean_value
# FROM labeled_data as l;
#
# SELECT * FROM cleaned_data WHERE outlier ORDER BY id, time LIMIT 100;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# 100 rows affected.
# Returning data to local variable result_2b

# %%
# Do not delete/edit this cell
result_2b.DataFrame().to_csv('results/result_2b.csv', index=False)

# %%
grader.check("q2b")
# Out:
# q2b results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Question 3: Entity Resolution
#
# ### Question 3a
# There is a lot of mess in this dataset related to entity names. As a start, have a look at all of the distinct values in the `units` field of the `metadata` table. What do you notice about these values? Are there any duplicates?
#
# <!--
# BEGIN QUESTION
# name: q3a
# manual: true
# points: 0
# -->

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 3b
#
# Sometimes, entity resolution is as simple as a text transformation. For example, how many unique `units` values are there, and how many would there be if we ignored case (upper vs. lower case)? Your output should be a table with one row and two columns; the first column should contain the number of unique `units` values, and the second column should contain the number of unique `units` values if we ignored case. The two columns can have arbitrary names.
#
# <!--
# BEGIN QUESTION
# name: q3bm
# manual: true
# points: 0
# -->

# %%
# %sql select * from metadata LIMIT 10
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 10 rows affected.
# [('fb5267b9-8cf4-5710-979e-5ab7d617e6e5', 'Main Electric Meter (kWh)', '2000 Carleton Street', 'kWh'),
#  ('4e7e5872-a3f7-5300-8433-b4dfd0254cb1', 'Main Electric Meter Demand (kW)', '2000 Carleton Street', 'kW'),
#  ('a2fbb537-3e9c-5c47-94c9-2b5cc3735f48', 'Main Electric Meter Min (kW)', '2000 Carleton Street', 'kW'),
#  ('4eb9d406-9aeb-56ab-aa9d-aaa368679e1f', 'Main Electric Meter Instantaneous (kW)', '2000 Carleton Street', 'kW'),
#  ('3c44bdad-d1a9-5155-b786-fb2ce6e1e76e', 'Main Electric Meter Max (kW)', '2000 Carleton Street', 'kW'),
#  ('1ec76d24-e7a8-5b02-ad54-1e0c00c3f408', 'Voltage phase A-B (Volts)', '2200 Bancroft Way', 'Volts'),
#  ('70c50787-e685-5ad3-84db-3094bda63bb6', 'Voltage phase B-C (Volts)', '2200 Bancroft Way', 'Volts'),
#  ('ab8cc53d-e9ad-51b9-9383-0dc812d5a7da', 'Apparent Power (kVA)', '2200 Bancroft Way', 'kVA'),
#  ('bca43b3a-d3c9-53e8-ab76-c473722e065c', 'Voltage phase B-N (Volts)', '2200 Bancroft Way', 'Volts'),
#  ('27ada1cb-1e7d-52b0-b768-164090b9d821', 'Present Demand (subinterval) (kW)', '2200 Bancroft Way', 'subinterval')]

# %%
# %%sql result_3b <<
# SELECT count(distinct(units)) as unique, count(distinct(lower(units))) as lower  from metadata
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 1 rows affected.
# Returning data to local variable result_3b

# %% [markdown]
# <!-- END QUESTION -->
#
# <!--
# BEGIN QUESTION
# name: q3b
# points: 1
# -->

# %%
result_3b
# Out:
# [(34, 29)]

# %%
# Do not delete/edit this cell
result_3b.DataFrame().to_csv('results/result_3b.csv', index=False)

# %%
grader.check("q3b")
# Out:
# q3b results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 3c
#
# Arguably we shouldn't care about these alternative unit labels, *as long as each sensor class uses a single value of `units` for all its sensor ids*. After all, maybe the capitalization means something to somebody!
#
# Write a SQL query that returns single row with one column of value `true` if the condition in italics above holds, or a single row with one column of value `false` otherwise. Please do not hard code this query - we reserve the right to penalize your score if you do so.
#
# <!--
# BEGIN QUESTION
# name: q3cm
# manual: true
# points: 0
# -->

# %%
# %%sql result_3c <<
# with unit as(
#     select id, count((units))
#     from metadata
#     group by id),
#
# newCount as(
#     select *,
#     case when count = 1 then true
#     when count = 0 then false
#     end as t
#     from unit)
#
# select (count(newCount)  filter (where t = true) = 9509) from newCount
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 1 rows affected.
# Returning data to local variable result_3c

# %%
result_3c
# Out:
# [(True,)]

# %% [markdown]
# <!-- END QUESTION -->
#
# <!--
# BEGIN QUESTION
# name: q3c
# points: 1
# -->

# %%
# Do not delete/edit this cell
result_3c.DataFrame().to_csv('results/result_3c.csv', index=False)

# %%
grader.check("q3c")
# Out:
# q3c results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 3d
#
# Moving on, have a look at the `real_estate_metadata` table---starting with the distinct values in the `location` field! What do you notice about these values?
#
# <!--
# BEGIN QUESTION
# name: q3d
# manual: true
# points: 0
# -->

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# ### Question 3e
#
# It turns out this table was the result of an [OCR scan](https://en.wikipedia.org/wiki/Optical_character_recognition). We'll just clean up the `location` column for now, and leave you to imagine the effort to do a full cleanup of all columns.
#
# To provide some useful utility functions, we have preloaded Postgres' extension packages for "fuzzy" string matching and trigrams for you. You can use any of the string functions in those packages if you like ([as documented here for fuzzystrmatch](https://www.postgresql.org/docs/current/fuzzystrmatch.html) or [here for pg_trgm](https://www.postgresql.org/docs/current/pgtrgm.html)).
#
# We also created a lookup table of canonical names, `uc_locations`.
#
# Now, using any of the string functions you like (or none at all!), write a SQL query that returns the columns `(building_name, address, location, clean_location)` where `clean_location` contains the best match from `uc_locations.loc_name`. You may find that you can't clean up everything with the string functions, so your view may have to include some specific logic for cases in the data that have to be handled "manually". You can choose to do this question in whatever manner you wish as long as your query does not use `CREATE TABLE`, `INSERT INTO`, or `UPDATE`.

# %%
# %sql select distinct(location) from real_estate_metadata LIMIT 20
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 15 rows affected.
# [('LOS ANGELES',),
#  ('FRANCISC O',),
#  ('SYSTEMWI DE',),
#  ('SAN DSAIENG O',),
#  ('FRANCISC SOAN',),
#  ('SANTA CRUZ',),
#  ('AG FIELD STAT',),
#  ('IRVINE',),
#  ('RIVERSIDE',),
#  ('BERKELEY',),
#  ('SANTA BARBARA',),
#  ('DAVIS',),
#  ('FRANCISC OSAN',),
#  ('MERCED',),
#  ('SAN DIEGO',)]

# %%
# %sql select * from uc_locations
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 12 rows affected.
# [(1, 'AG FIELD STAT'),
#  (2, 'BERKELEY'),
#  (3, 'DAVIS'),
#  (4, 'IRVINE'),
#  (5, 'LOS ANGELES'),
#  (6, 'MERCED'),
#  (7, 'RIVERSIDE'),
#  (8, 'SAN DIEGO'),
#  (9, 'SAN FRANCISCO'),
#  (10, 'SANTA BARBARA'),
#  (11, 'SANTA CRUZ'),
#  (12, 'SYSTEMWIDE')]

# %%
# %%sql result_3e <<
# with cte as(
#     SELECT r.building_name, r.address, r.location, uc.loc_name,
#     word_similarity(r.location, uc.loc_name) as distance
#     from real_estate_metadata as r, uc_locations as uc),
#
# cte2 as(SELECT building_name, address, location , max(distance) as distance
#     from cte
#     group by building_name,address,location)
#
# SELECT building_name, address,location, loc_name as clean_location from cte natural join cte2;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 5276 rows affected.
# Returning data to local variable result_3e

# %%
result_3e
# Out:
# [('CLEARY', '2424 CHANNING', 'BERKELEY', 'BERKELEY'),
#  ('WALNUT19 25', '1925 WALNUT', 'BERKELEY', 'BERKELEY'),
#  ('ERCHLDE DCNTR', '2339 HASTE', 'BERKELEY', 'BERKELEY'),
#  ('MRI MODLR II', 'CORE 2C1A5M4P-6U0S', 'BERKELEY', 'BERKELEY'),
#  ('UNIV 2154- 60', 'UNIVERSIT 2Y55', 'BERKELEY', 'BERKELEY'),
#  ('HAVENS', 'PANORAMI C25 W5 AY', 'BERKELEY', 'BERKELEY'),
#  ('HAVENS GR', 'PANORAMI 2C9 W99A Y', 'BERKELEY', 'BERKELEY'),
#  ('BOAT HOUSE', 'GLASCOC K STREET', 'BERKELEY', 'BERKELEY'),
#  ('BOAT EBRIGHT', '303 DERBY AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('BOAT SHED', '303 DERBY AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('PIEDMON2 232', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MCENERN EY', '1750 ARCH STREET', 'BERKELEY', 'BERKELEY'),
#  ('MCENERN EY GR', '1750 ARCH STREET', 'BERKELEY', 'BERKELEY'),
#  ('ENERGYBI OBLD', 'CORE 3C2A0M0P --U S', 'BERKELEY', 'BERKELEY'),
#  ('REGATTA3 200A', '3300 R32E0G0A -T- TA', 'BERKELEY', 'BERKELEY'),
#  ('REGATTA3 200B', '3300 REGATTA', 'BERKELEY', 'BERKELEY'),
#  ('CAMPBELL', 'CORE C28A5M0PUS', 'BERKELEY', 'BERKELEY'),
#  ('TELEGRPH 2850', 'TELEGRAP H1053', 'BERKELEY', 'BERKELEY'),
#  ('FSH REC CNTR', 'MONROE STREET', 'BERKELEY', 'BERKELEY'),
#  ('HEARST26 07', '2607 HEARST', 'BERKELEY', 'BERKELEY'),
#  ('PIEDMON2 224', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BOWDITC2 334', '2334 ABONNWAD ITCH', 'BERKELEY', 'BERKELEY'),
#  ('HASTE253 7', 'HEAD ACNONMAP LEX', 'BERKELEY', 'BERKELEY'),
#  ('BOWDITC2 420', 'HEAD CANONMAP LEX', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 536', 'HEAD ACNONMAP LEX', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 538', 'HEAD CANONMAP LEX', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 536A', 'HEAD CANONMAP LEX', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 538A', 'HEAD COMPLEX', 'BERKELEY', 'BERKELEY'),
#  ('BOWDITC2 350', '2350 BOWDITCH', 'BERKELEY', 'BERKELEY'),
#  ('MANVILLE', '2100 CHANNING', 'BERKELEY', 'BERKELEY'),
#  ('MARTINEZ COM', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 521', '2521 CHANNING', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 547', '2547 2C7H0A0NNING', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 1', 'HEARST 2A7V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 2', 'HEARST A27V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 3', 'HEARST A27V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 4', 'HEARST 2A7V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 5', 'HEARST 2A7V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 6', 'HEARST 2A7V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 7', 'HEARST 2A7V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 8', 'HEARST A27V0E0', 'BERKELEY', 'BERKELEY'),
#  ('FOOTHILL 9', 'HEARST AVE', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 535', '2535 CHANNING', 'BERKELEY', 'BERKELEY'),
#  ('WARREN', '2195 HEARST', 'BERKELEY', 'BERKELEY'),
#  ('HEARST FLD A', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('RESSTUS RVBLD', '2610 CHANNING', 'BERKELEY', 'BERKELEY'),
#  ('SWTCHGR STN 5', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HILLSUBS TATN', 'CYCLOTR O23N3 3R OAD', 'BERKELEY', 'BERKELEY'),
#  ('JACKSON', 'COLLEGE A20V0E NUE', 'BERKELEY', 'BERKELEY'),
#  ('GRAY RES GH', 'CENTENNI 1A8L9 D3R LIEV E', 'BERKELEY', 'BERKELEY'),
#  ('LE ROY1893', 'ROY A26V5E0N UE', 'BERKELEY', 'BERKELEY'),
#  ('RH1 RCHR1 STIAN', 'DURANT A26V5E0', 'BERKELEY', 'BERKELEY'),
#  ('SLOTTMA N', 'DURANT AVE', 'BERKELEY', 'BERKELEY'),
#  ('RH2 TOWLE', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('RH2 WADA', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('STANLEY', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STARR LIB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HEARST FLD S', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SUTARDJA DAI', 'CORE CANAMNAP US', 'BERKELEY', 'BERKELEY'),
#  ('HASTE253 7A', 'HEAD COMPLEX', 'BERKELEY', 'BERKELEY'),
#  ('WELLMAN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('NORTH GATE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('ART GALLERY', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SPROUL', 'CORE 2C6A0M0PUS', 'BERKELEY', 'BERKELEY'),
#  ('CLOYNE COURT', 'RIDGE ROAD', 'BERKELEY', 'BERKELEY'),
#  ('HARMON DIVNG', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('ALUMNI HOUSE', 'CORE C22A2M0PUS', 'BERKELEY', 'BERKELEY'),
#  ('FOUNDER S BLD', 'BANCROF T', 'BERKELEY', 'BERKELEY'),
#  ('PARKING NW', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BIRGE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('PIEDMON2 240', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LS ADDITION', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DURANT', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('NW AN FACIL', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BOWLES', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LAW', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CHEIT', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HAAS STU BLD', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HAAS FAC BLD', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SODA', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CHANNIN2 515', '2515 CHANNING', 'BERKELEY', 'BERKELEY'),
#  ('PIEDMON2 234', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MAXWELL RR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STRAWBE RY RR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('WITTER RR', 'RD/STADIU CME RNIMTEWNANYI', 'BERKELEY', 'BERKELEY'),
#  ('HUDSON FLD', 'AL/STRAW BRY CYN', 'BERKELEY', 'BERKELEY'),
#  ('PIEDMON2 222', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('COLLEGE2 251', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DWIGHT24 27', '2427 DWIGHT', 'BERKELEY', 'BERKELEY'),
#  ('DWIGHT TLRA', '2427 DWIGHT', 'BERKELEY', 'BERKELEY'),
#  ('DWIGHT TLRB', '2427 DWIGHT', 'BERKELEY', 'BERKELEY'),
#  ('WHEELER BIC', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HAZ MAT FAC', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CALIFORNI A', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STADIUM', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SIMPSONS AHPC', 'CORE C22A2M2PUS', 'BERKELEY', 'BERKELEY'),
#  ('TANG CENTER', 'BANCROF T', 'BERKELEY', 'BERKELEY'),
#  ('LEWIS', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DWINELLE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GARDNER STACK', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DOE ANNEX', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MOFFITT', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DOE LIBRARY', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MINOR ADDITN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MINOR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 1', 'PEAK & CGERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 4A', 'PEAK & CGERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 4B', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 5', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 6A', 'PEAK & CGERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 6B', 'PEAK & CGERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 7A', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 7B', 'PEAK & CGERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 7C', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 7D', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 8', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 9', 'PEAK & CENTENNI', 'BERKELEY', 'BERKELEY'),
#  ('JENSEN PR BX', 'CORE CGARMIZPZULYS', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 9A', 'PEAK & CENTENNI', 'BERKELEY', 'BERKELEY'),
#  ('CHEMGEN ERATR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('EDWARDS FLD', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SWTCHGR STN 4', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SWTCHGR STN 1', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MCLAUGH LIN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BLUM HALL', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DAVIS', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MOSES', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CORY', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DWIGHT29 39', 'SMYTH/FE RNWALD', 'BERKELEY', 'BERKELEY'),
#  ('SMYTH HOUSE', 'SMYTH/FE RNWALD', 'BERKELEY', 'BERKELEY'),
#  ('FAC CLUB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MULFORD', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GIANNINI', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GILMAN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GIRTON', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GREEK THEATR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HAAS PAVIL', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('REC SPRT FAC', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HAVILAND', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HEARST GYM', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HEARST MIN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HESSE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HILGARD', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ("O'BRIEN", 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MORGAN', 'CORE 2C2A9M9PUS', 'BERKELEY', 'BERKELEY'),
#  ('I HOUSE', 'PIEDMONT AVE', 'BERKELEY', 'BERKELEY'),
#  ('SIMON', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('KIOSK WEST', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('KIOSK EAST', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LAWSON ADIT', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LE CONTE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('VALLEY LSB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GIAUQUE LAB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DWINELLE AN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('DONNER LAB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('MORRISO N', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HERTZ', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HARGROV E LIB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('ARCH AND ENG', 'CORE C18A0M1PUS', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD NRLAB', 'WALNUT STREET', 'BERKELEY', 'BERKELEY'),
#  ('STRAWBC ENTER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('UNIV H GH', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('UNIV HOUSE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('UNIV H SHED', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LI KA SHING', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('ANTHONY', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SATHER TOWER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SENIOR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SOUTH', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('KROEBER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STEPHENS', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STERN', 'CORE 2C0A0M0PUS', 'BERKELEY', 'BERKELEY'),
#  ('CARLETO2 000', 'CARLETO N', 'BERKELEY', 'BERKELEY'),
#  ('UCB ART MUSE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD21 20', '2120 OXFORD', 'BERKELEY', 'BERKELEY'),
#  ('UC GARAGE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD19 90', '1990 OXFORD', 'BERKELEY', 'BERKELEY'),
#  ('WHEELER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('FAC CLUB W', 'CORE C18A0M1PUS', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD SHED', 'WALNUT 1S8T0R1E ET', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD COLD1', 'WALNUT 1S8T0R1E ET', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD COLD2', 'WALNUT SGTRRIZEZELTY', 'BERKELEY', 'BERKELEY'),
#  ('EMERGEN ST A', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('EMERGEN ST B', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('HILL PUMP HS', 'PEAK & ECLELNSTWEONNRI', 'BERKELEY', 'BERKELEY'),
#  ('PARKING C', 'TH ST/CHANNI', 'BERKELEY', 'BERKELEY'),
#  ('UNIVERSIT Y', '2199 ADDISON', 'BERKELEY', 'BERKELEY'),
#  ('PEOPLPAR K RR', 'HASTE & BOWDITCH', 'BERKELEY', 'BERKELEY'),
#  ('CEV MULFORD', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HELLMAN TEN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SWTCHGR STN 2', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SWTCHGR STN 3', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CEV DOE', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CEV RSF', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('VAN HEUIT TC', 'CORE CEANMTPEUNSNI', 'BERKELEY', 'BERKELEY'),
#  ('BYERLY SEIS', 'AL/STRAW 2B6R1Y2  CYN', 'BERKELEY', 'BERKELEY'),
#  ('UNDERHIL L', 'CHANNING WAY', 'BERKELEY', 'BERKELEY'),
#  ('STEAM TUNNEL', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STRAWB ISOLA', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STRAWB COOPA', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STRAWB BUNKR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STRAWB COOPB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('STRAWB FEED', 'CORE C20A0M PUS', 'BERKELEY', 'BERKELEY'),
#  ('BG 1718', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1719 ARID', 'CENTENNI A18L0 D3RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD IN GH', 'WALNUT S18T0R5E ET', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD INSCT', 'WALNUT 2S0T0R EET', 'BERKELEY', 'BERKELEY'),
#  ('BG 1726 OFC', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1727 KIOS', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1729 GNHS', 'CENTENNI AL DRIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1731 RSCH', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1732 PROP', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1733 LATH', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1734 OFFC', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1736 GNHS', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1737 VP', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1740 SHOP', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1741 FERN', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1742 COMN', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1743 LATH', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1744 RR', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1745 NAVY', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1746 BARN', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1747 GH2', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1749 ANNX', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1750 GH1', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1751 CONF', 'CENTENNI 2A0L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1751A ORN', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1752 TROP', 'CENTENNI A20L0 D RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('BG 1753 SHOP', 'CENTENNI 1A8L0 D1RIVE -', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD STOR', 'WALNUT STREET', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD LATH', 'WALNUT STREET', 'BERKELEY', 'BERKELEY'),
#  ('BARROWS', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('RMHC1C ONE', 'CORE 2C6A5M0PUS', 'BERKELEY', 'BERKELEY'),
#  ('FREEBOR N', 'DURANT A26V5E0', 'BERKELEY', 'BERKELEY'),
#  ('RH1 CHENEY', 'DURANT A26V5E0', 'BERKELEY', 'BERKELEY'),
#  ('RH1 DEUTSCH', 'DURANT 2A6V5E0', 'BERKELEY', 'BERKELEY'),
#  ('RH1 PUTNAM', 'DURANT 2A6V5E0', 'BERKELEY', 'BERKELEY'),
#  ('RH1 CENTRAL', 'DURANT AVE', 'BERKELEY', 'BERKELEY'),
#  ('RH2 CUNNINHM', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('RH2 DAVIDSON', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('RH2 GRIFFITH', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('RH2 EHRMAN', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('RH2 CENTRAL', '2650 HASTE ST', 'BERKELEY', 'BERKELEY'),
#  ('HAAS CLUB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('TOLMAN', 'CORE C24A2M5PUS', 'BERKELEY', 'BERKELEY'),
#  ('ATHERTO2 425', 'ATHERTO 1N751', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD RES', 'WALNUT HSTERAEREST', 'BERKELEY', 'BERKELEY'),
#  ('PARKING A', 'AVE/SCENI C AVE', 'BERKELEY', 'BERKELEY'),
#  ('PARKING B', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BG 1781 ADMN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LATIMER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('ETCHEVE RRY', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CHAVEZ', 'CORE C17A4M1PUS', 'BERKELEY', 'BERKELEY'),
#  ('OXFORD GPB', 'WALNUT SHTERAEREST', 'BERKELEY', 'BERKELEY'),
#  ('PARKING H', 'AVE/LALO MA AVE', 'BERKELEY', 'BERKELEY'),
#  ('BECHTEL CNTR', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('GPB TEACH', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('EVANS', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('KING UNION', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('PARKNG UNION', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BARKER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('FULTON22 23', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('BANCROF 2401', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('KOSHLAN D', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('WURSTER', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CALVIN LAB', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('LAWRENC E', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('PIMENTEL', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('ZELLERBA CH', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('RH3 DINING', '2400 DURANT', 'BERKELEY', 'BERKELEY'),
#  ('RH3 SPROUL', '2400 DURANT', 'BERKELEY', 'BERKELEY'),
#  ('RH3 NORTON', '2400 DURANT', 'BERKELEY', 'BERKELEY'),
#  ('RH3 SPENSBLK', '2400 DURANT', 'BERKELEY', 'BERKELEY'),
#  ('RH3 PRIESTLY', '2400 DURANT', 'BERKELEY', 'BERKELEY'),
#  ('TAN', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('HILDEBRA ND', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('SILVER', '7 GAUSS WGRAIYZZLY', 'BERKELEY', 'BERKELEY'),
#  ('SILVER STOR', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('SPACESCI ANX', 'PEAK & CENTENNI', 'BERKELEY', 'BERKELEY'),
#  ('SPACESCI ADD', '8 GAUSS WAY', 'BERKELEY', 'BERKELEY'),
#  ('CHERN HALL', '17 GAUSS WCLAAYRK', 'BERKELEY', 'BERKELEY'),
#  ('CKC 1', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 2', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 3', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 4', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 5', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 6', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 7', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 8MASLACH', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 9', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 10', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 11', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 12', 'KERR CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CKC 13', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 14CONF C', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 15', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 16', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 17KELLER', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 18', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 19', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 20', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC C21KSCT ORAG', 'KERR CLAAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('22OLDGY M', 'KERR CALAMRPKU S', 'BERKELEY', 'BERKELEY'),
#  ('CKC 25RECCTR', 'KERR C16A0M1PUS', 'BERKELEY', 'BERKELEY'),
#  ('ALLSTON1 601', 'ALLSTON WAY', 'BERKELEY', 'BERKELEY'),
#  ('VIRGINI227 5', '2275 V21IR1G1 INIA', 'BERKELEY', 'BERKELEY'),
#  ('BANCROF 2111', 'BANCROF 2T200', 'BERKELEY', 'BERKELEY'),
#  ('BANCROF 2200', 'BANCROF T2436', 'BERKELEY', 'BERKELEY'),
#  ('BANCROF 2440', 'BANCROF T1995', 'BERKELEY', 'BERKELEY'),
#  ('UNIVERS1 995', 'UNIVERSIT Y', 'BERKELEY', 'BERKELEY'),
#  ('CKC 23ARCHIV', 'CORE CAMPUS', 'BERKELEY', 'BERKELEY'),
#  ('CKC 24RECCTR', 'CORE 5C5A MPUS', 'BERKELEY', 'BERKELEY'),
#  ('SF WOODS', 'LAGUNA S55T  - UNEX', 'BERKELEY', 'BERKELEY'),
#  ('SF WOODS ANX', 'LAGUNA ST - UNEX', 'BERKELEY', 'BERKELEY'),
#  ('MIDDLEHA LSF', 'LAGUNA S55T  - UNEX', 'BERKELEY', 'BERKELEY'),
#  ('RICHARDS N', 'LAGUNA S10T2 -0 UNEX', 'BERKELEY', 'BERKELEY'),
#  ('FSH 100', 'JACKSON S94T5R EET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 101', 'OHLONE A94V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 102', 'OHLONE A94V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 103', 'OHLONE 7A5V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 104', 'OHLONE 7A5V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 105', 'OHLONE 7A5V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 106', 'OHLONE 7A5V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 107', 'OHLONE 6A0V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 108', 'OHLONE 6A0V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 109', 'OHLONE A60V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 110', 'OHLONE 6A0V5E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 111', 'OHLONE 3A0V0E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 112', 'GOODING W30A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 113', 'GOODING 3W0A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 114', 'GOODING W30A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 115', 'GOODING 8W1A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 116', 'OHLONE A98V0E', 'BERKELEY', 'BERKELEY'),
#  ('FSH 117', 'OHLONE A10V4E0', 'BERKELEY', 'BERKELEY'),
#  ('FSH 118', 'JACKSON STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 119', 'JACKSON 1S0T4R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 120', 'JACKSON S43T5R EET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 121', 'GOODING 4W3A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 122', 'GOODING 4W3A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 123', 'GOODING 7W3A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 124', 'GOODING W73A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 125', 'GOODING W73A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 126', 'GOODING 1W0A7Y0', 'BERKELEY', 'BERKELEY'),
#  ('FSH 127', 'JACKSON 1S0T7R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 128', 'JACKSON S10T7R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 129', 'JACKSON 1S1T1R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 130', 'JACKSON S11T1R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 131', 'JACKSON 1S1T1R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 132', 'JACKSON 1S1T1R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 133', 'JACKSON S11T1R0E ET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 134', 'JACKSON STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 135', '786 RED OAK AVE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 136', '786 RED 6O0A0K R AEVDE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 139', 'OAK AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 140', '747 RED OAK AVE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 141', '747 RED OAK AVE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 143', 'GOODING W60A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 144', 'GOODING WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY1', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY2', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY3', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY4', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY6', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY7', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY8', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDRY9', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH LAUNDR10', '1125 8TH S59T0R EET', 'BERKELEY', 'BERKELEY'),
#  ('FSH CD FACIL', 'GOODING WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH WASTE', '1125 8TH S60T0R REEDT', 'BERKELEY', 'BERKELEY'),
#  ('FSH 137', 'OAK AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 138', '1005 6TH S80T5R EET', 'BERKELEY', 'BERKELEY'),
#  ('FSH 142', 'KINKEAD W71A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 145', 'KINKEAD W86A5Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 146', 'KINKEAD W52A5Y RED', 'BERKELEY', 'BERKELEY'),
#  ('FSH 149', 'OAK A58V5E RNEUDE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 150', 'OAK 7A3V0E NUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 151', 'KINKEAD WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 152', 'KINKEAD W53A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 153', 'KINKEAD W58A0Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 154', 'OHLONE AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 155', '415 KULA GULF WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 156', '675 KULA GULF WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 157', '725 KULA G40U5L RF EWDA Y', 'BERKELEY', 'BERKELEY'),
#  ('FSH 158', 'OAK AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 147', '1000 6TH 5S4T0R REEDT', 'BERKELEY', 'BERKELEY'),
#  ('FSH 148', 'OAK AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 159', '670 KULA GULF WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 160', '420 KULA 4G0U0L F WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 161', 'OHLONE A42V5E NUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 162', 'LIBERTY S68H5IPWAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 163', 'LIBERTY SHIP WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 164', '735 WEST END WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 165', '625 WEST END WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 166', '515 WEST END WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 167', '305 WEST E33N5D  WAY', 'BERKELEY', 'BERKELEY'),
#  ('FSH 168', 'OHLONE 4A8V5E NUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 169', 'OHLONE A55V5E NUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH 170', 'OHLONE AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('HEARST24 81', '2481 2H1E6A1R ST', 'BERKELEY', 'BERKELEY'),
#  ('UNIVERS2 161', 'UNIVERSIT 1Y608', 'BERKELEY', 'BERKELEY'),
#  ('FOURTHS TREET', 'FOURTH 3S8T6R0E1E ET.', 'BERKELEY', 'BERKELEY'),
#  ('HR CABIN', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('WORKSHO P', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR UP BARN', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR OFFICE', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR DAVIS LHARB', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('BUNKHOU SE', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR LINSDALE', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR RANCH HSE', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR LOW HBARRN', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('SCHOOL HSR', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('SCHOOL GR', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR ARNOLD', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR AVIARY', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR BELL', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR BETTY LAB', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR CHICK COP', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR FANNY CAB', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR HALLI P', 'CARMEL VALLEY', 'BERKELEY', 'BERKELEY'),
#  ('HR LAB', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HOMESTE AD', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR MHRU SEUM', 'CARMEL 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('RESTROO MHR', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('ROBERTS OHRN', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('SADDLE RHMR', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('SCOTTBA RN', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR CONF BLDG', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR MOD HSE 1', 'CARMEL V38A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR MOD HSE 2', 'CARMEL VALLEY', 'BERKELEY', 'BERKELEY'),
#  ('TANGLEW OOD H', '168 HARRISON', 'BERKELEY', 'BERKELEY'),
#  ('TANGLEW OOD S', '168 HARRISON', 'BERKELEY', 'BERKELEY'),
#  ('TANGLEW OOD G', '168 4H9A2R7RISON', 'BERKELEY', 'BERKELEY'),
#  ('RUSS LEUS RS', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS LEUS 20', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS LEUS 30', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS WTHR IN', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS PMP HS', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS NOR TNK', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS BLACKSM', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS SCRN 1', 'HAPPY VALLEY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS SCRN 2', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS WAT TNK', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS CHEM ST', 'HAPPY BVLAULLEE OYA K', 'BERKELEY', 'BERKELEY'),
#  ('BOR BARN', 'RANCH BRLEUSE ROVAEK', 'BERKELEY', 'BERKELEY'),
#  ('BOR CBOABRI N', 'RANCH BRLEUSE ROVAEK', 'BERKELEY', 'BERKELEY'),
#  ('OUTHOUS E', 'RANCH R49E2S7E RVE', 'BERKELEY', 'BERKELEY'),
#  ('RUSS CHICKN', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS BARN', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS COT RES', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS COT GAR', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS GAR REP', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS LATH', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS WOODSHD', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS STD HSE', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS STOR TR', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS WELL 2', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS LEAN TO', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS STOR 1', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS STOR 2', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS OFFICE', 'HAPPY 4V9A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS PMP HS1', 'HAPPY VALLEY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS PMP HS2', 'HAPPY V49A2L7L EY', 'BERKELEY', 'BERKELEY'),
#  ('RUSS BARNSHD', 'HAPPY 3V8A6L0L1E EY.', 'BERKELEY', 'BERKELEY'),
#  ('HR HALLISEY', 'CARMEL VALLEY', 'BERKELEY', 'BERKELEY'),
#  ('BLAKE SHED', '70 RINCON ROAD', 'BERKELEY', 'BERKELEY'),
#  ('BLAKE GHSE', '70 RINCON R42O0A1D', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ PRIVY', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ KIOSK', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ STORAG', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH LAUNDR', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH PROPAN', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH BLAKSM', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH LUMBER', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH SHOP', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH GRDNSH', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH OUTHSE', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT GRNHS', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT HOUSE', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT WOOD', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT PROPAN', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT CHICKN', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT ANIMAL', 'WILDERNE SS LODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT OUTHS1', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR CT OUTHS2', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL PSRHOPAN', 'WILDERNE S11S6 L1O6 DGE', 'BERKELEY', 'BERKELEY'),
#  ('APARTMN T', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH WOOD SHED', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH JOHNSON', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH KIT DINE', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH LAB CSHLASS', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('LEOPOLD CSHK', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('LOWERBA TH', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH SMHE ADOW', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('LEOPOLD OSH', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('RESIDENC ESH', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('STORSHE DSH', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('TREEHOU SE', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH BURNSIDE', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH TOOL SHED', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH TRAP SH ED', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('EASTCABI SNH', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('WESTCABI SNH', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('NRTHCABI N', 'SAGEHEN ROAD', 'BERKELEY', 'BERKELEY'),
#  ('SH STHHCABIN', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('LEOPOLD CB', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('SH OSHB SERVE', 'SAGEHEN R11O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('UPPERBAT SHH', 'SAGEHEN 1R1O6A1D6', 'BERKELEY', 'BERKELEY'),
#  ('HWYGARA GE', 'SAGEHEN R10O5A0D SAN', 'BERKELEY', 'BERKELEY'),
#  ('GILL STORAGE', 'PABLO 4A2V0E1  - GILL', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ CONFER', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ LAB', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ LATH', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL WOOD', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL BATH', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL WILDER', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL CABOAK', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL CABFIR', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL CABBAY', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL CABPIN', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL CABLIT', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR WL FOX', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ HDQRTS', 'WILDERNE S42S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ GARAGE', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ POWER', 'WILDERNE SS LODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ WITEHS', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR AH HOUSE', 'WILDERNE 4S2S0 L1ODGE', 'BERKELEY', 'BERKELEY'),
#  ('AR HQ PREP', 'WILDERNE 2S9S8 L ODGE', 'BERKELEY', 'BERKELEY'),
#  ('FSH GROUNDS', 'OHLONE AVENUE', 'BERKELEY', 'BERKELEY'),
#  ('FSH COMP TR', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH STDY TR', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH STORAGE', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH ADMIN', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH COMM CTR', '1125 8TH STREET', 'BERKELEY', 'BERKELEY'),
#  ('FSH PAINTING', '1125 8TH 1S0T5R0E SEATN', 'BERKELEY', 'BERKELEY'),
#  ('GILL BIOCLIM', 'PABLO A10V5E0  -S GAINLL', 'BERKELEY', 'BERKELEY'),
#  ('GILL SERVICE', 'PABLO A47VTEH -  &G ILL', 'BERKELEY', 'BERKELEY'),
#  ('NOR REG LIB', 'HOFFMAN 1B3L0V1D .', 'BERKELEY', 'BERKELEY'),
#  ('RFS 121', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 197', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 471', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 151', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 112', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 102', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 117', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 100', 'SOUTH 46TH', 'BERKELEY', 'BERKELEY'),
#  ('RFS 120', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 282', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 110', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 116', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 114', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 118', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 125', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 128', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 111', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 149', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 150', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 152', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 155', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 154', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 159', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 160', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 161', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 162', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 163', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 164', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 165', 'SOUTH 46TH', 'BERKELEY', 'BERKELEY'),
#  ('RFS 167', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 175', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 177', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 178', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 180', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 185', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 190', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 485', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 451', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 176', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 478', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 450', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 491', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 420', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 153', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 421', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 479', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 276', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 488', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 480', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 452', 'SOUTH 46TH', 'BERKELEY', 'BERKELEY'),
#  ('RFS 453', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 454', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 158', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 277', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 275', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 482', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 470', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 472', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 473', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 486', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 194', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 196', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 195', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 113', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 474', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 475', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 280', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 484', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 445', 'SOUTH 1463T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 460', 'SOUTH 4163T01H', 'BERKELEY', 'BERKELEY'),
#  ('RFS 300', 'SOUTH 46TH', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 2C', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 2D', 'PEAK & GCERNIZTZELNYNI', 'BERKELEY', 'BERKELEY'),
#  ('FSBR 2E', 'PEAK & CENTENNI', 'BERKELEY', 'BERKELEY'),
#  ('EDUC OPP', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WALKER', 'CORE C13A8M0PUS', 'DAVIS', 'DAVIS'),
#  ('OAKV COLDBOX', 'OAKVILLE GRADE RD', 'DAVIS', 'DAVIS'),
#  ('ROOT SHED', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 174', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HART', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FAC SHED 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 20', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COLE G', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH BEEF B', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH BEEF SCA', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('THE BARN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COLE D', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 36', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VALLEY OAK', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV OFF', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WALNUT', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COTTONW OOD', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ROBBNS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COLE F', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COLE E', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HCD CMPTR LB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 16', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 13', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 14', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CENGAR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FAC SHOPS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FAC MECH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('YOUNG', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS Y', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SILO', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('NORTH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SOUTH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH 006', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 9', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WELL 5', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FAC SERVICES', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ENOL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR J11', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR 1534', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR 1533', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR 1532', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR 1531', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CA RPTR TRLR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR 1537', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SVM GEN TR F', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SVM GEN TR E', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR R- 4', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS TR R- 3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VCTI-DIS TR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LTRAS OFC TR', 'KINSELLA LANE', 'DAVIS', 'DAVIS'),
#  ('UNIV HOUSE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV ST E', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG PRC LAB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH HORSE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CRUESS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HICKEY GYM', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GR OFFICE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H GRNDS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HUB HEIT LC', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HCD ADMIN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('EVERSN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WICKSN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ROBBNS ANX', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 116', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WYATT', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 24', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH GRNDS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH 003', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ELDERBER RY', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LIB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ART ANNEX', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 019', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('EH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH 004', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 040', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 22', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PP LAB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HUNT', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ASMDSN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PFH A', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P FLD LAB 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P FLD LAB 1', 'CORE C16A MPUS', 'DAVIS', 'DAVIS'),
#  ('CHANCLR RES', 'COLLEGE PARK', 'DAVIS', 'DAVIS'),
#  ('WILLOW', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 15', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MECH SEW', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH SHEEP SH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VMEYER', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COWELL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MU', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 7', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 12', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VEG BULB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS L-1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS Q', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS N', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS P', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS M', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VET BEACH LB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('STHCAMP FLB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS M-4', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VET LAB AN A', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS E', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VET LG AN F', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HARING', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HB 1 GAR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH SHOP', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH HAY', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH FEED LAB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH HOP BARN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HOP CLD', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD 4', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PH D 2&3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HEADQTR S', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV SCAL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HANGAR', 'AIRPORT RD', 'DAVIS', 'DAVIS'),
#  ('HANGOF', 'AIRPORT RD', 'DAVIS', 'DAVIS'),
#  ('BEE HS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HC 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HC 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HC 2 GAR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HE 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HE 1 GAR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HOAGLD', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CNG FACILITY', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 19', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS Z-3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('RADXR2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS K-1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH HORSE SH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HCD CHLD DEV', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TOOMEY RR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TOOMEY STOR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 26', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SCREEN 002', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FIRE HS HPKN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HANGAR LOUNG', 'AIRPORT RD', 'DAVIS', 'DAVIS'),
#  ('HANGAR NO 3', 'AIRPORT RD', 'DAVIS', 'DAVIS'),
#  ('ARS STORE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P SHOP', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VRHIES', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS X 6', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS X 7', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PHYTO', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH 019', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH 014', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HOAGLD ANX', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('DAIRY', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ASTF 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ASTF 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('DCFEED', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('DCSHDS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG PRC SHED', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VEG STORE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS R6', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H R6', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AGRON FLB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WS&E FLB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ZOOFLB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AGSURP CUST', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CUSTOD STRGE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH DAIRY SCA', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SEG GILMORE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SEG BIXBY', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SEG MALCOLM', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FRBORN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('YOUNG STORE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WS&E HYD L2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SCREEN 009', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AGRON INST', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H 050', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H 040', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS H', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HUTCH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CHE OFC&LAB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SEG RYERSON', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV SH 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV SH 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV SH 3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AG SERV SHOP', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH FM GRIND', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH FEED MILL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS V', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COBALT', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('OLSON', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS Z-2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SCREEN 010', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PP CHEM STOR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS Z-1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AQUATIC BIO', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('JUNGERM AN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SPROUL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS K-3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('STARLING PEN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PFH B', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PFH D', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PFH C', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PFH F', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PFH E', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('APCARU', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS HDQTRS', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH FEED LOT', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH FEED SCA', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH HOP SCA', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LAB AN BLD C', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS Q-1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS G-1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS H-1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('FOOD SC&TECH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS J1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MANN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MRAK', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PRIM CTR ADM', 'COUNTY ROAD 98', 'DAVIS', 'DAVIS'),
#  ('PRIM CTR LAB', 'COUNTY ROAD 98', 'DAVIS', 'DAVIS'),
#  ('PRIM CTR ANB', 'COUNTY R21O2A D 98', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1100', 'SOLANO 2P1A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1200', 'SOLANO P24A2R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 4200', 'SOLANO P23A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 4300', 'SOLANO P25A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 4100', 'SOLANO P24A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1400', 'SOLANO P22A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1500', 'SOLANO P21A6R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1600', 'SOLANO P20A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 4000', 'SOLANO PARK CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1800', 'SOLANO P34A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1700', 'SOLANO 3P2A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3900', 'SOLANO 3P1A6R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3700', 'SOLANO P37A2R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2100', 'SOLANO P36A6R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2000', 'SOLANO 3P7A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2200', 'SOLANO P31A0R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3600', 'SOLANO 3P0A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3500', 'SOLANO P30A2R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2400', 'SOLANO 4P6A2R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3400', 'SOLANO 4P5A0R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3200', 'SOLANO P41A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2600', 'SOLANO 4P4A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3100', 'SOLANO 4P3A8R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3000', 'SOLANO P42A0R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2700', 'SOLANO 4P2A6R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2800', 'SOLANO P20A0R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 4400', 'SOLANO P22A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1300', 'SOLANO P36A0R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 1900', 'SOLANO P38A4R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2300', 'SOLANO PARK CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2500', 'SOLANO 4P3A2R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 2900', 'SOLANO P45A6R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3300', 'SOLANO P32A2R K CIR', 'DAVIS', 'DAVIS'),
#  ('SOLANO 3800', 'SOLANO 1P2A0R0K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7600', 'ORCHARD 1P2A1R2K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7400', 'ORCHARD P12A2R4K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7200', 'ORCHARD P12A4R8K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6800', 'ORCHARD 1P3A0R0K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6700', 'ORCHARD P13A1R2K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6500', 'ORCHARD 1P3A2R4K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6300', 'ORCHARD P13A4R8K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5900', 'ORCHARD P13A6R0K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5600', 'ORCHARD P13A6R6K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5700', 'ORCHARD P13A8R4K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5300', 'ORCHARD P13A9R0K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5200', 'ORCHARD P12A0R6K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7500', 'ORCHARD 1P2A1R8K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7300', 'ORCHARD P12A3R0K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7100', 'ORCHARD 1P2A3R6K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6900', 'ORCHARD 1P3A1R8K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6400', 'ORCHARD PARK CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6200', 'ORCHARD P13A4R2K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6000', 'ORCHARD P13A5R4K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5800', 'ORCHARD 1P3A7R2K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5500', 'ORCHARD P13A9R6K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5100', 'ORCHARD 1P4A0R2K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5000', 'ORCHARD P12A4R2K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 7000', 'ORCHARD P13A0R6K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6600', 'ORCHARD P13A3R6K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 6100', 'ORCHARD 1P3A7R8K  CIR', 'DAVIS', 'DAVIS'),
#  ('ORCHARD 5400', 'ORCHARD P56A5R K CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN CENT C', 'REGAN H60A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN CAMPO', 'REGAN 5H7A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN RIENDA', 'REGAN H55A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN NOVA', 'REGAN H53A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN TALARA', 'REGAN 5H1A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN PALOMA', 'REGAN 5H0A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN INDIO', 'REGAN H52A5L L CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN SERENO', 'REGAN HALL CIR', 'DAVIS', 'DAVIS'),
#  ('REGAN MECH', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H 003', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 301', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 302', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 303', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 304', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 305', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 306', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 307', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 308', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 309', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 310', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 311', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 312', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 313', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 314', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 315', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 316', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 317', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 318', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 319', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 320', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VET LAB AN B', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('VET LAB AN D', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MAPLE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('P HS B', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ROTATNG RM 1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LATH 001', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WS&E DRN L2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CHEM', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CHEM ANX', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS U2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('APCARU ANBLD', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MUSIC', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ART', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WRIGHT HALL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('BUCKEYE', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('PUTAH CRK LG', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GR SHED PUTA', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH SHEEP', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H 006', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 601', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 602', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 603', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 604', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 605', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 606', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 607', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 608', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 609', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 610', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 611', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 612', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 613', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 614', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 615', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 616', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 617', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 618', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 619', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 620', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('HD H 009', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ASMDSN ANNEX', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 070', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('GRHS 071', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('BAINER', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WEATHER STA', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS W3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TELCOM', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ATERCS W1', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('COMMUNI T', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TEC MECHANIC', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TEC EQUIPT', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MECH 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WELLMN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('KING', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 116', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 117', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 118', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 119', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 120', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 123', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 124', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('STORER', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('NELSON HALL', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LEUKEMIA BRN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ISOLAT HOSP', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('CALF BARN', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('LEUKEMIA LAB', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('DAIRY ABAHRN 2', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('MATERNIT Y', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('AH FEED SHED', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 126', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 127', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 128', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('TB 129', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WYATT SNACK', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('WYATT RR', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('SURGE 3', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ('ARS DL-5', 'CORE CAMPUS', 'DAVIS', 'DAVIS'),
#  ...]

# %%
# Do not delete/edit this cell
result_3e.DataFrame().sort_values(['clean_location', 'building_name', 'address']).iloc[::10].to_csv('results/result_3e.csv', index=False)

# %%
grader.check("q3e")
# Out:
# q3e results: All test cases passed!

# %% [markdown]
# ## Question 4: Interpolating Missing Data
# Real-world data, real-world problems. Our sensors should be reporting every 15 minutes, but you can be sure that we're missing some data. Here we will fix it. It's a bit more involved than what we looked at in class!
#
# ### Question 4a: Finding missing readings
# In the `data` table, the `id` column identifies a unique sensor. Sensor readings should be recorded every 15 minutes from every sensor. Are we missing any readings, and if so which ones? We will focus on readings that are separated by at least 30 minutes or more; readings that are \[0-30) minutes apart are considered to be fine.
#
# To answer this question you'll need to read up a bit on [SQL timestamps](https://www.postgresql.org/docs/current/datatype-datetime.html) and [Functions for manipulating datetime types](https://www.postgresql.org/docs/current/functions-datetime.html). Have a particular look at the following:
# - The [date_trunc](https://www.postgresql.org/docs/current/functions-datetime.html#FUNCTIONS-DATETIME-TRUNC) function will quantize times to the nearest unit of your choosing. E.g. to round the `time` field to the nearest minute you can say `date_trunc('minute', time)`. **You'll need to quantize to minutes right away before you worry about missing readings.**
# - There are various ways to enter constant intervals of time as strings. E.g. a 30 minute interval can be written as `interval '30 minutes'` or `'30 minutes'::interval`. See [date/time input](https://www.postgresql.org/docs/current/datatype-datetime.html#DATATYPE-INTERVAL-INPUT) for more info.
# - You can do arithmetic on date/time types [as documented here](https://www.postgresql.org/docs/current/functions-datetime.html#FUNCTIONS-DATETIME-TRUNC). That will handle all the weird periodicities of clocks and calendars for you. Pay attention to the input and output types of these functions!
# - Alternatively, the [EXTRACT](https://www.postgresql.org/docs/current/functions-datetime.html#FUNCTIONS-DATETIME-EXTRACT) function is sometimes handy. Note the special `EXTRACT(EPOCH FROM ...)` case. This converts a timestamp into an integer representing the number of seconds since midnight, 1/1/1970 (the dawn of [UNIX time](https://en.wikipedia.org/wiki/Unix_time)!)  You can do normal integer comparisons and arithmetic on the results.
# - You will need to use the [lag](https://www.geeksforgeeks.org/postgresql-lag-function/) function as the window function.
#
#
# Create a view called `gaps` that augments the `data` schema with three columns:
# - `lagtime` is the quantized time of the previous reading for that sensor (relative to the current row for a particular row)
# - `lagvalue` is the value of the previous reading for that sensor
# - `timediff` is the difference in quantized time between this reading and the previous reading
#
# The view should only contain rows where `timediff` is **greater than or equal to 30 minutes**.

# %%
# %%sql result_4a <<
# CREATE OR REPLACE VIEW gaps AS
# with lag as(
#     select *,
#     date_trunc('minute', LAG(time) OVER (PARTITION BY id ORDER BY time)) AS lagtime,
#     LAG(value) OVER (PARTITION by id) as lagvalue
#     FROM data),
#
#     lag2 as(
#     SELECT *, date_trunc('minute', time) - lagtime as timediff from lag)
#
# SELECT * FROM lag2
#     WHERE EXTRACT (MINUTE FROM timediff) >= 30 OR extract(HOUR FROM timediff) >= 1 OR extract(DAY FROM timediff) >= 1;
#
# SELECT * FROM gaps ORDER BY id, time LIMIT 10;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# 10 rows affected.
# Returning data to local variable result_4a

# %%
# Do not delete/edit this cell
result_4a.DataFrame().to_csv('results/result_4a.csv', index=False)

# %%
grader.check("q4a")
# Out:
# q4a results: All test cases passed!

# %% [markdown]
# ### Question 4b: Creating tuples for the missing readings
# Now we need to manufacture new tuples to fill in the gaps. For example, if you had a tuple from id `abc` timestamped at 1PM today and the next tuple in time from `abc` was timestamped at 1:45PM, you'll need to manufacture two new tuples with id `abc` and `NULL` values: one timestamped at 1:15PM and another timestamped at 1:30PM. We will worry about replacing the `NULL` values in the next step.
#
# To manufacture tuples not related to stored data in the database, we'll need to use a *table-valued function* as we did in lecture 12 (when we manufactured data from a normal distribution). The table-valued function we want here is `generate_series` [(documented here)](https://www.postgresql.org/docs/current/functions-srf.html), which we will use to generate *and sequentially timestamp* the right number of tuples to match the number of tuples we found missing.
#
# To get a feel for `generate_series`, consider the following simple query that generates a table of integers with intervals of size 3 between them.

# %%
# %%sql
# SELECT *
#   FROM generate_series(1, 10, 3);
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 4 rows affected.
# [(1,), (4,), (7,), (10,)]

# %% [markdown]
# Now, we can use `generate_series` in a `LATERAL JOIN` query: for each tuple on the left of the `LATERAL` it will produce a series based on the values of that tuple. So for example, we can generate 2 tuples for each tuple of `uc_locations` as follows:

# %%
# %%sql
# SELECT loc_id, loc_name, length(loc_name), newval
#   FROM uc_locations u,
#        LATERAL generate_series(length(loc_name), length(loc_name) + 2, 2) AS newval;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# 24 rows affected.
# [(1, 'AG FIELD STAT', 13, 13),
#  (1, 'AG FIELD STAT', 13, 15),
#  (2, 'BERKELEY', 8, 8),
#  (2, 'BERKELEY', 8, 10),
#  (3, 'DAVIS', 5, 5),
#  (3, 'DAVIS', 5, 7),
#  (4, 'IRVINE', 6, 6),
#  (4, 'IRVINE', 6, 8),
#  (5, 'LOS ANGELES', 11, 11),
#  (5, 'LOS ANGELES', 11, 13),
#  (6, 'MERCED', 6, 6),
#  (6, 'MERCED', 6, 8),
#  (7, 'RIVERSIDE', 9, 9),
#  (7, 'RIVERSIDE', 9, 11),
#  (8, 'SAN DIEGO', 9, 9),
#  (8, 'SAN DIEGO', 9, 11),
#  (9, 'SAN FRANCISCO', 13, 13),
#  (9, 'SAN FRANCISCO', 13, 15),
#  (10, 'SANTA BARBARA', 13, 13),
#  (10, 'SANTA BARBARA', 13, 15),
#  (11, 'SANTA CRUZ', 10, 10),
#  (11, 'SANTA CRUZ', 10, 12),
#  (12, 'SYSTEMWIDE', 10, 10),
#  (12, 'SYSTEMWIDE', 10, 12)]

# %% [markdown]
# Notice how the 2 values it generates are the length of the `loc_name`, and the length + 2. You might want to play with the query above to make sure you understand the documentation for `generate_series` and `LATERAL`.

# %% [markdown]
# Ok, on to your task!
#
# Create a view `complete` that contains the tuples from `data` as well as new tuples that fill in any gaps greater than or equal to 30 minutes. Each gap should be filled by adding tuples in increments of 15 minutes from the *start* of the gap, **with `NULL` as the value**. You probably want to use your `gaps` view as well as `generate_series` to do this!
#
# **Hint:** the lower and upper bounds in generate_series (in pseudocode) should be `(lagtime + 15 minutes, time - 15 minutes)`.

# %%
# %sql drop view complete
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# []

# %%
# %%sql result_4b <<
# CREATE OR REPLACE VIEW complete AS
#     with cte as(select newval as time,id, NULL as value FROM GAPS,
#     LATERAL generate_series(lagtime + '15 minutes'::interval, time - '15 minutes'::interval, '15 minutes'::interval) as newval
#     )
# SELECT time, id , CAST(value AS INT) from cte
# UNION
# SELECT time,id ,value from data;
#
# SELECT * FROM complete ORDER BY id, time LIMIT 100;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# 100 rows affected.
# Returning data to local variable result_4b

# %%
# Do not delete/edit this cell
result_4b.DataFrame().to_csv('results/result_4b.csv', index=False)

# %%
grader.check("q4b")
# Out:
# q4b results: All test cases passed!

# %% [markdown]
# ### Question 4c: Linear Interpolation
# *Note: If you struggled with the previous subparts of this problem, you can use our table `complete_provided` instead of your `complete` table in this subpart.*
#
# Now, given the `complete` view or the `complete_provided` table, the remaining task is to do linear interpolation to fill in the missing values we manufactured in Step 2. We have code from **this semester's** Lecture 14 (Data Cleaning) we can reuse here! In particular, your database already includes the UDA `coalesce_agg` we used in lecture (you can use it directly, there's no need to redefine it).
#
# But note that in Lecture 14's example of linear interpolation we had a field called `entry_rank` that was used to order *all* the records in the table. By contrast, here the ordering we care about is the series of `time` for each sensor `id` *independently*. You will need to make minor changes to adapt the linear interpolation code from class to work here.
#
# Create a view `likely_data` that contains all the tuples from `complete`, with an additional column called `interpolated` that contains a copy of `value` if it is non-NULL, otherwise an interpolated value based on linear interpolation *per sensor id over time*. Please **retain all additional columns created from forward and backward passes** (there should be 10 columns in the view - the order of the columns does not matter.) The three cells below correspond to the forward, backward, and final passes from lecture.

# %%
# %%sql
# CREATE OR REPLACE VIEW forward AS
# SELECT *,
#        SUM(CASE WHEN value IS NULL THEN 0 ELSE 1 END)
#          OVER (PARTITION BY id ORDER BY time ) AS run,
#        coalesce_agg(value) OVER (PARTITION BY id ORDER BY time) AS run_start,
#        CASE WHEN value IS NULL
#               THEN lead(value, 1) OVER (PARTITION BY id ORDER BY time)
#             ELSE NULL
#        END AS nextval
#   FROM complete_provided;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# []

# %%
# %%sql
# CREATE OR REPLACE VIEW backward AS
# SELECT *,
#        CASE WHEN value IS NOT NULL THEN value
#             ELSE coalesce_agg(nextval) OVER (PARTITION BY id,run ORDER BY time DESC)
#        END AS run_end,
#        count(*) OVER (PARTITION BY id, run) AS run_size,
#        count(*) OVER (PARTITION BY id,run ORDER BY time) AS run_rank
#   FROM forward;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# []

# %%
# %%sql result_4c <<
# CREATE OR REPLACE VIEW likely_data AS
# SELECT *,
#        run_start + (run_rank-1)*((run_end-run_start)/(run_size))
#          AS interpolated
#   FROM backward;
#
#
# SELECT * FROM likely_data WHERE run_size > 2 ORDER BY id, time LIMIT 100;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/template1
#  * postgresql://jovyan@127.0.0.1:5432/ucb_buildings
# Done.
# 100 rows affected.
# Returning data to local variable result_4c

# %%
# Do not delete/edit this cell
result_4c.DataFrame().to_csv('results/result_4c.csv', index=False)

# %%
grader.check("q4c")
# Out:
# q4c results: All test cases passed!

# %% [markdown]
# ## Congratulations! You have finished Project 3.
#
# Run the following cell to zip and download the results of your queries. You will also need to run the export cell at the end of the notebook.
#
# **For submission on Gradescope, you will need to submit BOTH the proj3.zip file genreated by the export cell and the results.zip file generated by the following cell.**
#
# **Common submission issues:** You MUST submit the generated zip files (not folders) to the autograder. However, Safari is known to automatically unzip files upon downloading. You can fix this by going into Safari preferences, and deselect the box with the text "Open safe files after downloading" under the "General" tab. If you experience issues with downloading via clicking on the link, you can also navigate to the project 3 directory within JupyterHub (remove `proj3.ipynb` from the url), and manually download the generated zip files. Please post on Ed if you encounter any other submission issues.

# %%
from IPython.display import display, FileLink

# !zip -r results.zip results
results_file = FileLink('./results.zip', result_html_prefix="Click here to download: ")
display(results_file)

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export()
